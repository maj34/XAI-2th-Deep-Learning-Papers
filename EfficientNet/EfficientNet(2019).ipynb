# %%
from google.colab import drive
drive.mount('efficientnet')
# Out:
# Mounted at efficientnet

# %%
# import package

# model
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
from torch import optim

# dataset and transformation
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision import models
import os

# display images
from torchvision import utils
import matplotlib.pyplot as plt
# %matplotlib inline

# utils
import numpy as np
from torchsummary import summary
import time
import copy

# %% [markdown]
# # 1. 데이터셋 불러오기
# 데이터셋은 torchvision 패키지에서 제공하는 STL10 dataset을 이용하겠습니다. STL10 dataset은 10개의 label을 갖으며 train dataset 5000개, test dataset 8000개로 구성됩니다.

# %%
# specify path to data
path2data = '/content/efficientnet/MyDrive/data'

# if not exists the path, make the directory
if not os.path.exists(path2data):
    os.mkdir(path2data)

# load dataset
train_ds = datasets.STL10(path2data, split='train', download=True, transform=transforms.ToTensor()) #데이터셋 나누기, transform tensor로
val_ds = datasets.STL10(path2data, split='test', download=True, transform=transforms.ToTensor())

print(len(train_ds))
print(len(val_ds))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 5000
# 8000

# %%
# define transformation 
transformation = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Resize(224)
])

# apply transformation to dataset 
train_ds.transform = transformation
val_ds.transform = transformation

# make dataloader
train_dl = DataLoader(train_ds, batch_size=32, shuffle=True) #배치사이즈 32, 셔플
val_dl = DataLoader(val_ds, batch_size=32, shuffle=True)

# %%
# check sample images
def show(img, y=None):
    npimg = img.numpy()
    npimg_tr = np.transpose(npimg, (1, 2, 0))
    plt.imshow(npimg_tr)

    if y is not None:
        plt.title('labels:' + str(y))

np.random.seed(10)
torch.manual_seed(0)

grid_size=4
rnd_ind = np.random.randint(0, len(train_ds), grid_size)

x_grid = [train_ds[i][0] for i in rnd_ind]
y_grid = [val_ds[i][1] for i in rnd_ind]

x_grid = utils.make_grid(x_grid, nrow=grid_size, padding=2)
plt.figure(figsize=(10,10))
show(x_grid, y_grid)

# %% [markdown]
# # 2. 모델 구축하기
# 코드는 https://github.com/zsef123/EfficientNets-PyTorch/blob/master/models/effnet.py 를 참고했습니다.
#
# https://github.com/katsura-jp/efficientnet-pytorch/blob/master/model/efficientnet.py

# %%
# Swish activation function 
# Swish는 매우 깊은 신경망에서 ReLU보다 높은 정확도를 달성한다고 한다.
class Swish(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)

# check
if __name__ == '__main__':
    x = torch.randn(3, 3, 224, 224)
    model = Swish()
    output = model(x)
    print('output size:', output.size())
# Out:
# output size: torch.Size([3, 3, 224, 224])

# %%
# url="https://drive.google.com/file/d/1NmfWPAOSVqeWlv8PUuAvR0ZBo3ift5sF/view?usp=sharing" #link 부분을 구글 드라이브에서 생성한 공유 링크로 변경해주면 된다.
# path='https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
# size="width=\"\" "+"height =\"\" "
# tag="<img src='"+path+"' "+size+"/><br>"
# print(" ▶ Path : ", path)

# print('\n',"▶ Tag : ", tag)

# %% [markdown]
# <img src='https://drive.google.com/uc?export=download&id=11NVcmm9tEzWs2x7NF-6D-ceJlqFTmkfq' width=600 height =600 /><br>

# %%
x.size(1)
# Out:
# 3

# %%
# SE Block을 사용함
# squeeze 즉, pooling을 통해 1x1 size로 줄여서 정보를 압축한 뒤에 excitation 즉 압축된 정보들을 weighted layer와 비선형 activation function으로 각 채널별 중요도를 계산하여 기존 input에 곱을 해주는 방식.
# SE block의 목적은 컨볼루션을 통해 생성된 특성을 채널당 중요도를 고려해서 재보정(recalibration)하는 것
class SEBlock(nn.Module):
    def __init__(self, in_channels, r=4): #r은 왜 4?
        super().__init__()

        self.squeeze = nn.AdaptiveAvgPool2d((1,1)) #1*1 사이즈 압축
        self.excitation = nn.Sequential(
            nn.Linear(in_channels, in_channels * r),
            Swish(),
            nn.Linear(in_channels * r, in_channels),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.squeeze(x)
        x = x.view(x.size(0), -1)
        x = self.excitation(x)
        x = x.view(x.size(0), x.size(1), 1, 1)
        return x

# check
if __name__ == '__main__':
    x = torch.randn(3, 56, 17, 17)
    model = SEBlock(x.size(1))
    output = model(x)
    print('output size:', output.size())
# Out:
# output size: torch.Size([3, 56, 1, 1])

# %%
#학습 시에 stochastic depth를 사용하므로 이 기능 추가
#vanishing gradient로 인해 학습이 느리게 되는 문제를 완화시키고자 stochastic depth 라는 randomness에 기반한 학습 방법
#stochastic depth는 layer의 부분을 무작위로 drop하는 방법이다. 그리고 identity function으로 bypass를 진행합니다. Stochastic depth란 network의 depth를 학습 단계에 random하게 줄이는 것을 의미
# 즉 layer 전체를 skip하는 방법으로 sample 단위로 drop하는것이 아니다.
#복잡하고 큰 데이터 셋에서는 별다를 효과를 보지는 못한다고 함


# MBConv는 Mobilenet v2에서 제안된 inverted residual block을 의마하고 모델 아키텍처에서 1과 6은 expand ratio이다.
class MBConv(nn.Module):
    expand = 6
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, se_scale=4, p=0.5):
        super().__init__()
        # first MBConv is not using stochastic depth
        self.p = torch.tensor(p).float() if (in_channels == out_channels) else torch.tensor(1).float()

        self.residual = nn.Sequential(
            nn.Conv2d(in_channels, in_channels * MBConv.expand, 1, stride=stride, padding=0, bias=False),
            nn.BatchNorm2d(in_channels * MBConv.expand, momentum=0.99, eps=1e-3),
            Swish(),
            nn.Conv2d(in_channels * MBConv.expand, in_channels * MBConv.expand, kernel_size=kernel_size,
                      stride=1, padding=kernel_size//2, bias=False, groups=in_channels*MBConv.expand),
            nn.BatchNorm2d(in_channels * MBConv.expand, momentum=0.99, eps=1e-3),
            Swish()
        )

        self.se = SEBlock(in_channels * MBConv.expand, se_scale) #reduce layer

        self.project = nn.Sequential(
            nn.Conv2d(in_channels*MBConv.expand, out_channels, kernel_size=1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(out_channels, momentum=0.99, eps=1e-3)
        )

        self.shortcut = (stride == 1) and (in_channels == out_channels) #Drop connect  여기서 사용한 drop out은 batch 중에 0.2(drop_connect_rate)의 확률로 entire conv를 drop 하는 Stochastic depth라는 방법이고

    def forward(self, x):
        # stochastic depth 
        # skip하는 기준은 베르누이 랜덤 변수에 의해 정히진다. 여기서 만약 i번쨰 레이어의 베르누이 랜덤 변수가 1이라면 active하고 아니라면 inactive하게 됩니다. 
        if self.training:
            if not torch.bernoulli(self.p): #레이어 스킵
                return x

        x_shortcut = x
        x_residual = self.residual(x)
        x_se = self.se(x_residual)

        x = x_se * x_residual
        x = self.project(x)

        if self.shortcut:
            x= x_shortcut + x #skip connection

        return x

# check
if __name__ == '__main__':
    x = torch.randn(3, 16, 24, 24)
    model = MBConv(x.size(1), x.size(1), 3, stride=1, p=1)
    model.train()
    output = model(x)
    x = (output == x)
    print('output size:', output.size(), 'Stochastic depth:', x[1,0,0,0])
# Out:
# output size: torch.Size([3, 16, 24, 24]) Stochastic depth: tensor(False)

# %%
class SepConv(nn.Module):
    expand = 1 # 첫번쨰 stage에서는 expand가 1임 
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, se_scale=4, p=0.5):
        super().__init__()
        # first SepConv is not using stochastic depth
        self.p = torch.tensor(p).float() if (in_channels == out_channels) else torch.tensor(1).float()

        self.residual = nn.Sequential(
            nn.Conv2d(in_channels * SepConv.expand, in_channels * SepConv.expand, kernel_size=kernel_size,
                      stride=1, padding=kernel_size//2, bias=False, groups=in_channels*SepConv.expand),
            nn.BatchNorm2d(in_channels * SepConv.expand, momentum=0.99, eps=1e-3),
            Swish()
        )

        self.se = SEBlock(in_channels * SepConv.expand, se_scale)

        self.project = nn.Sequential(
            nn.Conv2d(in_channels*SepConv.expand, out_channels, kernel_size=1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(out_channels, momentum=0.99, eps=1e-3)
        )

        self.shortcut = (stride == 1) and (in_channels == out_channels)

    def forward(self, x):
        # stochastic depth
        if self.training:
            if not torch.bernoulli(self.p):
                return x

        x_shortcut = x
        x_residual = self.residual(x)
        x_se = self.se(x_residual)

        x = x_se * x_residual
        x = self.project(x)

        if self.shortcut:
            x= x_shortcut + x

        return x

# check
if __name__ == '__main__':
    x = torch.randn(3, 16, 24, 24)
    model = SepConv(x.size(1), x.size(1), 3, stride=1, p=1)
    model.train()
    output = model(x)
    # stochastic depth check
    x = (output == x)
    print('output size:', output.size(), 'Stochastic depth:', x[1,0,0,0])
# Out:
# output size: torch.Size([3, 16, 24, 24]) Stochastic depth: tensor(False)

# %% [markdown]
# <img src='https://drive.google.com/uc?export=download&id=1NmfWPAOSVqeWlv8PUuAvR0ZBo3ift5sF' width="600" height ="600" /><br>

# %% [markdown]
# 모델 구조 참고
# https://lynnshin.tistory.com/13

# %%
repeats = [1, 2, 2, 3, 3, 4, 1]
depth = 1.
width = 1.
repeats = [int(x*depth) for x in repeats]

# %%
(1-0.5)/sum(repeats)
# Out:
# 0.03125

# %%
#대형 모델 주변에서 depth width resolution를 검색하면 더 나은 성능을 얻을 수 있지만 대형 모델에서는 cost가 비싸다. 그래서 이방법에서는 small baseline network에서 다른 모든 모델에 동일한 스케일링 계수를 사용하여 이 문제를 해결합니다.


class EfficientNet(nn.Module):
    def __init__(self, num_classes=10, width_coef=1., depth_coef=1., scale=1., dropout=0.2, se_scale=4, stochastic_depth=False, p=0.5): # drop_connect_rate 0.2, keep_prob 0.8,
        super().__init__()
        channels = [32, 16, 24, 40, 80, 112, 192, 320, 1280] #stage 1~9
        repeats = [1, 2, 2, 3, 3, 4, 1] #stage2~stage8 layers 블록의 갯수
        strides = [1, 2, 2, 2, 1, 2, 1] #stride
        kernel_size = [3, 3, 5, 3, 5, 5, 3] 
        depth = depth_coef
        width = width_coef

        channels = [int(x*width) for x in channels]
        repeats = [int(x*depth) for x in repeats]

        # stochastic depth 
        if stochastic_depth:
            self.p = p
            self.step = (1 - 0.5) / (sum(repeats) - 1)
        else:
            self.p = 1
            self.step = 0


        # efficient net
        self.upsample = nn.Upsample(scale_factor=scale, mode='bilinear', align_corners=False) # 주어진 다중 채널 1D (시간), 2D (공간) 또는 3D (체적) 데이터를 업 샘플링합니다.

        self.stage1 = nn.Sequential(
            nn.Conv2d(3, channels[0],3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(channels[0], momentum=0.99, eps=1e-3)
        )

        self.stage2 = self._make_Block(SepConv, repeats[0], channels[0], channels[1], kernel_size[0], strides[0], se_scale)

        self.stage3 = self._make_Block(MBConv, repeats[1], channels[1], channels[2], kernel_size[1], strides[1], se_scale)

        self.stage4 = self._make_Block(MBConv, repeats[2], channels[2], channels[3], kernel_size[2], strides[2], se_scale)

        self.stage5 = self._make_Block(MBConv, repeats[3], channels[3], channels[4], kernel_size[3], strides[3], se_scale)

        self.stage6 = self._make_Block(MBConv, repeats[4], channels[4], channels[5], kernel_size[4], strides[4], se_scale)

        self.stage7 = self._make_Block(MBConv, repeats[5], channels[5], channels[6], kernel_size[5], strides[5], se_scale)

        self.stage8 = self._make_Block(MBConv, repeats[6], channels[6], channels[7], kernel_size[6], strides[6], se_scale)

        self.stage9 = nn.Sequential(
            nn.Conv2d(channels[7], channels[8], 1, stride=1, bias=False),
            nn.BatchNorm2d(channels[8], momentum=0.99, eps=1e-3),
            Swish()
        ) 
        #Pooling & FC
        self.avgpool = nn.AdaptiveAvgPool2d((1,1)) 
        self.dropout = nn.Dropout(p=dropout)#0.2 
        self.linear = nn.Linear(channels[8], num_classes) #stage9  channel사용

    def forward(self, x):
        x = self.upsample(x)
        x = self.stage1(x)
        x = self.stage2(x)
        x = self.stage3(x)
        x = self.stage4(x)
        x = self.stage5(x)
        x = self.stage6(x)
        x = self.stage7(x)
        x = self.stage8(x)
        x = self.stage9(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), -1)
        x = self.dropout(x)
        x = self.linear(x)
        return x


    def _make_Block(self, block, repeats, in_channels, out_channels, kernel_size, stride, se_scale):
        strides = [stride] + [1] * (repeats - 1)
        layers = []
        for stride in strides:
            layers.append(block(in_channels, out_channels, kernel_size, stride, se_scale, self.p))
            in_channels = out_channels
            self.p -= self.step

        return nn.Sequential(*layers)

#이 논문에서는 MnasNet 과 거의 동일한 search space 하에서 AutoML을 통해 모델을 탐색하여 찾은 작은 모델을 EfficientNet-B0 라고 부르고있다. 
#Drop-out Rate : EfficientNet B0 → EfficientNet B7로 증가할 때, 선형적으로 0.2 → 0.5로 증가
def efficientnet_b0(num_classes=10):
    return EfficientNet(num_classes=num_classes, width_coef=1.0, depth_coef=1.0, scale=1.0,dropout=0.2, se_scale=4) #크기에 따라, 파라미터들에 따라 다른모델

def efficientnet_b1(num_classes=10):
    return EfficientNet(num_classes=num_classes, width_coef=1.0, depth_coef=1.1, scale=240/224, dropout=0.2, se_scale=4)

def efficientnet_b2(num_classes=10):
    return EfficientNet(num_classes=num_classes, width_coef=1.1, depth_coef=1.2, scale=260/224., dropout=0.3, se_scale=4)

def efficientnet_b3(num_classes=10):
    return EfficientNet(num_classes=num_classes, width_coef=1.2, depth_coef=1.4, scale=300/224, dropout=0.3, se_scale=4)

def efficientnet_b4(num_classes=10):
    return EfficientNet(num_classes=num_classes, width_coef=1.4, depth_coef=1.8, scale=380/224, dropout=0.4, se_scale=4)

def efficientnet_b5(num_classes=10):
    return EfficientNet(num_classes=num_classes, width_coef=1.6, depth_coef=2.2, scale=456/224, dropout=0.4, se_scale=4)

def efficientnet_b6(num_classes=10):
    return EfficientNet(num_classes=num_classes, width_coef=1.8, depth_coef=2.6, scale=528/224, dropout=0.5, se_scale=4)

def efficientnet_b7(num_classes=10):
    return EfficientNet(num_classes=num_classes, width_coef=2.0, depth_coef=3.1, scale=600/224, dropout=0.5, se_scale=4)


# check
if __name__ == '__main__':
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    x = torch.randn(3, 3, 224, 224).to(device)
    model = efficientnet_b0().to(device)
    output = model(x)
    print('output size:', output.size())
# Out:
# output size: torch.Size([3, 10])

# %%
# print model summary
model = efficientnet_b0().to(device)
summary(model, (3,224,224), device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#           Upsample-1          [-1, 3, 224, 224]               0
#             Conv2d-2         [-1, 32, 112, 112]             864
#        BatchNorm2d-3         [-1, 32, 112, 112]              64
#             Conv2d-4         [-1, 32, 112, 112]             288
#        BatchNorm2d-5         [-1, 32, 112, 112]              64
#            Sigmoid-6         [-1, 32, 112, 112]               0
#              Swish-7         [-1, 32, 112, 112]               0
#  AdaptiveAvgPool2d-8             [-1, 32, 1, 1]               0
#             Linear-9                  [-1, 128]           4,224
#           Sigmoid-10                  [-1, 128]               0
#             Swish-11                  [-1, 128]               0
#            Linear-12                   [-1, 32]           4,128
#           Sigmoid-13                   [-1, 32]               0
#           SEBlock-14             [-1, 32, 1, 1]               0
#            Conv2d-15         [-1, 16, 112, 112]             512
#       BatchNorm2d-16         [-1, 16, 112, 112]              32
#           SepConv-17         [-1, 16, 112, 112]               0
#            Conv2d-18           [-1, 96, 56, 56]           1,536
#       BatchNorm2d-19           [-1, 96, 56, 56]             192
#           Sigmoid-20           [-1, 96, 56, 56]               0
#             Swish-21           [-1, 96, 56, 56]               0
#            Conv2d-22           [-1, 96, 56, 56]             864
#       BatchNorm2d-23           [-1, 96, 56, 56]             192
#           Sigmoid-24           [-1, 96, 56, 56]               0
#             Swish-25           [-1, 96, 56, 56]               0
# AdaptiveAvgPool2d-26             [-1, 96, 1, 1]               0
#            Linear-27                  [-1, 384]          37,248
#           Sigmoid-28                  [-1, 384]               0
#             Swish-29                  [-1, 384]               0
#            Linear-30                   [-1, 96]          36,960
#           Sigmoid-31                   [-1, 96]               0
#           SEBlock-32             [-1, 96, 1, 1]               0
#            Conv2d-33           [-1, 24, 56, 56]           2,304
#       BatchNorm2d-34           [-1, 24, 56, 56]              48
#            MBConv-35           [-1, 24, 56, 56]               0
#            Conv2d-36          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-37          [-1, 144, 56, 56]             288
#           Sigmoid-38          [-1, 144, 56, 56]               0
#             Swish-39          [-1, 144, 56, 56]               0
#            Conv2d-40          [-1, 144, 56, 56]           1,296
#       BatchNorm2d-41          [-1, 144, 56, 56]             288
#           Sigmoid-42          [-1, 144, 56, 56]               0
#             Swish-43          [-1, 144, 56, 56]               0
# AdaptiveAvgPool2d-44            [-1, 144, 1, 1]               0
#            Linear-45                  [-1, 576]          83,520
#           Sigmoid-46                  [-1, 576]               0
#             Swish-47                  [-1, 576]               0
#            Linear-48                  [-1, 144]          83,088
#           Sigmoid-49                  [-1, 144]               0
#           SEBlock-50            [-1, 144, 1, 1]               0
#            Conv2d-51           [-1, 24, 56, 56]           3,456
#       BatchNorm2d-52           [-1, 24, 56, 56]              48
#            MBConv-53           [-1, 24, 56, 56]               0
#            Conv2d-54          [-1, 144, 28, 28]           3,456
#       BatchNorm2d-55          [-1, 144, 28, 28]             288
#           Sigmoid-56          [-1, 144, 28, 28]               0
#             Swish-57          [-1, 144, 28, 28]               0
#            Conv2d-58          [-1, 144, 28, 28]           3,600
#       BatchNorm2d-59          [-1, 144, 28, 28]             288
#           Sigmoid-60          [-1, 144, 28, 28]               0
#             Swish-61          [-1, 144, 28, 28]               0
# AdaptiveAvgPool2d-62            [-1, 144, 1, 1]               0
#            Linear-63                  [-1, 576]          83,520
#           Sigmoid-64                  [-1, 576]               0
#             Swish-65                  [-1, 576]               0
#            Linear-66                  [-1, 144]          83,088
#           Sigmoid-67                  [-1, 144]               0
#           SEBlock-68            [-1, 144, 1, 1]               0
#            Conv2d-69           [-1, 40, 28, 28]           5,760
#       BatchNorm2d-70           [-1, 40, 28, 28]              80
#            MBConv-71           [-1, 40, 28, 28]               0
#            Conv2d-72          [-1, 240, 28, 28]           9,600
#       BatchNorm2d-73          [-1, 240, 28, 28]             480
#           Sigmoid-74          [-1, 240, 28, 28]               0
#             Swish-75          [-1, 240, 28, 28]               0
#            Conv2d-76          [-1, 240, 28, 28]           6,000
#       BatchNorm2d-77          [-1, 240, 28, 28]             480
#           Sigmoid-78          [-1, 240, 28, 28]               0
#             Swish-79          [-1, 240, 28, 28]               0
# AdaptiveAvgPool2d-80            [-1, 240, 1, 1]               0
#            Linear-81                  [-1, 960]         231,360
#           Sigmoid-82                  [-1, 960]               0
#             Swish-83                  [-1, 960]               0
#            Linear-84                  [-1, 240]         230,640
#           Sigmoid-85                  [-1, 240]               0
#           SEBlock-86            [-1, 240, 1, 1]               0
#            Conv2d-87           [-1, 40, 28, 28]           9,600
#       BatchNorm2d-88           [-1, 40, 28, 28]              80
#            MBConv-89           [-1, 40, 28, 28]               0
#            Conv2d-90          [-1, 240, 14, 14]           9,600
#       BatchNorm2d-91          [-1, 240, 14, 14]             480
#           Sigmoid-92          [-1, 240, 14, 14]               0
#             Swish-93          [-1, 240, 14, 14]               0
#            Conv2d-94          [-1, 240, 14, 14]           2,160
#       BatchNorm2d-95          [-1, 240, 14, 14]             480
#           Sigmoid-96          [-1, 240, 14, 14]               0
#             Swish-97          [-1, 240, 14, 14]               0
# AdaptiveAvgPool2d-98            [-1, 240, 1, 1]               0
#            Linear-99                  [-1, 960]         231,360
#          Sigmoid-100                  [-1, 960]               0
#            Swish-101                  [-1, 960]               0
#           Linear-102                  [-1, 240]         230,640
#          Sigmoid-103                  [-1, 240]               0
#          SEBlock-104            [-1, 240, 1, 1]               0
#           Conv2d-105           [-1, 80, 14, 14]          19,200
#      BatchNorm2d-106           [-1, 80, 14, 14]             160
#           MBConv-107           [-1, 80, 14, 14]               0
#           Conv2d-108          [-1, 480, 14, 14]          38,400
#      BatchNorm2d-109          [-1, 480, 14, 14]             960
#          Sigmoid-110          [-1, 480, 14, 14]               0
#            Swish-111          [-1, 480, 14, 14]               0
#           Conv2d-112          [-1, 480, 14, 14]           4,320
#      BatchNorm2d-113          [-1, 480, 14, 14]             960
#          Sigmoid-114          [-1, 480, 14, 14]               0
#            Swish-115          [-1, 480, 14, 14]               0
# AdaptiveAvgPool2d-116            [-1, 480, 1, 1]               0
#           Linear-117                 [-1, 1920]         923,520
#          Sigmoid-118                 [-1, 1920]               0
#            Swish-119                 [-1, 1920]               0
#           Linear-120                  [-1, 480]         922,080
#          Sigmoid-121                  [-1, 480]               0
#          SEBlock-122            [-1, 480, 1, 1]               0
#           Conv2d-123           [-1, 80, 14, 14]          38,400
#      BatchNorm2d-124           [-1, 80, 14, 14]             160
#           MBConv-125           [-1, 80, 14, 14]               0
#           Conv2d-126          [-1, 480, 14, 14]          38,400
#      BatchNorm2d-127          [-1, 480, 14, 14]             960
#          Sigmoid-128          [-1, 480, 14, 14]               0
#            Swish-129          [-1, 480, 14, 14]               0
#           Conv2d-130          [-1, 480, 14, 14]           4,320
#      BatchNorm2d-131          [-1, 480, 14, 14]             960
#          Sigmoid-132          [-1, 480, 14, 14]               0
#            Swish-133          [-1, 480, 14, 14]               0
# AdaptiveAvgPool2d-134            [-1, 480, 1, 1]               0
#           Linear-135                 [-1, 1920]         923,520
#          Sigmoid-136                 [-1, 1920]               0
#            Swish-137                 [-1, 1920]               0
#           Linear-138                  [-1, 480]         922,080
#          Sigmoid-139                  [-1, 480]               0
#          SEBlock-140            [-1, 480, 1, 1]               0
#           Conv2d-141           [-1, 80, 14, 14]          38,400
#      BatchNorm2d-142           [-1, 80, 14, 14]             160
#           MBConv-143           [-1, 80, 14, 14]               0
#           Conv2d-144          [-1, 480, 14, 14]          38,400
#      BatchNorm2d-145          [-1, 480, 14, 14]             960
#          Sigmoid-146          [-1, 480, 14, 14]               0
#            Swish-147          [-1, 480, 14, 14]               0
#           Conv2d-148          [-1, 480, 14, 14]          12,000
#      BatchNorm2d-149          [-1, 480, 14, 14]             960
#          Sigmoid-150          [-1, 480, 14, 14]               0
#            Swish-151          [-1, 480, 14, 14]               0
# AdaptiveAvgPool2d-152            [-1, 480, 1, 1]               0
#           Linear-153                 [-1, 1920]         923,520
#          Sigmoid-154                 [-1, 1920]               0
#            Swish-155                 [-1, 1920]               0
#           Linear-156                  [-1, 480]         922,080
#          Sigmoid-157                  [-1, 480]               0
#          SEBlock-158            [-1, 480, 1, 1]               0
#           Conv2d-159          [-1, 112, 14, 14]          53,760
#      BatchNorm2d-160          [-1, 112, 14, 14]             224
#           MBConv-161          [-1, 112, 14, 14]               0
#           Conv2d-162          [-1, 672, 14, 14]          75,264
#      BatchNorm2d-163          [-1, 672, 14, 14]           1,344
#          Sigmoid-164          [-1, 672, 14, 14]               0
#            Swish-165          [-1, 672, 14, 14]               0
#           Conv2d-166          [-1, 672, 14, 14]          16,800
#      BatchNorm2d-167          [-1, 672, 14, 14]           1,344
#          Sigmoid-168          [-1, 672, 14, 14]               0
#            Swish-169          [-1, 672, 14, 14]               0
# AdaptiveAvgPool2d-170            [-1, 672, 1, 1]               0
#           Linear-171                 [-1, 2688]       1,809,024
#          Sigmoid-172                 [-1, 2688]               0
#            Swish-173                 [-1, 2688]               0
#           Linear-174                  [-1, 672]       1,807,008
#          Sigmoid-175                  [-1, 672]               0
#          SEBlock-176            [-1, 672, 1, 1]               0
#           Conv2d-177          [-1, 112, 14, 14]          75,264
#      BatchNorm2d-178          [-1, 112, 14, 14]             224
#           MBConv-179          [-1, 112, 14, 14]               0
#           Conv2d-180          [-1, 672, 14, 14]          75,264
#      BatchNorm2d-181          [-1, 672, 14, 14]           1,344
#          Sigmoid-182          [-1, 672, 14, 14]               0
#            Swish-183          [-1, 672, 14, 14]               0
#           Conv2d-184          [-1, 672, 14, 14]          16,800
#      BatchNorm2d-185          [-1, 672, 14, 14]           1,344
#          Sigmoid-186          [-1, 672, 14, 14]               0
#            Swish-187          [-1, 672, 14, 14]               0
# AdaptiveAvgPool2d-188            [-1, 672, 1, 1]               0
#           Linear-189                 [-1, 2688]       1,809,024
#          Sigmoid-190                 [-1, 2688]               0
#            Swish-191                 [-1, 2688]               0
#           Linear-192                  [-1, 672]       1,807,008
#          Sigmoid-193                  [-1, 672]               0
#          SEBlock-194            [-1, 672, 1, 1]               0
#           Conv2d-195          [-1, 112, 14, 14]          75,264
#      BatchNorm2d-196          [-1, 112, 14, 14]             224
#           MBConv-197          [-1, 112, 14, 14]               0
#           Conv2d-198            [-1, 672, 7, 7]          75,264
#      BatchNorm2d-199            [-1, 672, 7, 7]           1,344
#          Sigmoid-200            [-1, 672, 7, 7]               0
#            Swish-201            [-1, 672, 7, 7]               0
#           Conv2d-202            [-1, 672, 7, 7]          16,800
#      BatchNorm2d-203            [-1, 672, 7, 7]           1,344
#          Sigmoid-204            [-1, 672, 7, 7]               0
#            Swish-205            [-1, 672, 7, 7]               0
# AdaptiveAvgPool2d-206            [-1, 672, 1, 1]               0
#           Linear-207                 [-1, 2688]       1,809,024
#          Sigmoid-208                 [-1, 2688]               0
#            Swish-209                 [-1, 2688]               0
#           Linear-210                  [-1, 672]       1,807,008
#          Sigmoid-211                  [-1, 672]               0
#          SEBlock-212            [-1, 672, 1, 1]               0
#           Conv2d-213            [-1, 192, 7, 7]         129,024
#      BatchNorm2d-214            [-1, 192, 7, 7]             384
#           MBConv-215            [-1, 192, 7, 7]               0
#           Conv2d-216           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-217           [-1, 1152, 7, 7]           2,304
#          Sigmoid-218           [-1, 1152, 7, 7]               0
#            Swish-219           [-1, 1152, 7, 7]               0
#           Conv2d-220           [-1, 1152, 7, 7]          28,800
#      BatchNorm2d-221           [-1, 1152, 7, 7]           2,304
#          Sigmoid-222           [-1, 1152, 7, 7]               0
#            Swish-223           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-224           [-1, 1152, 1, 1]               0
#           Linear-225                 [-1, 4608]       5,313,024
#          Sigmoid-226                 [-1, 4608]               0
#            Swish-227                 [-1, 4608]               0
#           Linear-228                 [-1, 1152]       5,309,568
#          Sigmoid-229                 [-1, 1152]               0
#          SEBlock-230           [-1, 1152, 1, 1]               0
#           Conv2d-231            [-1, 192, 7, 7]         221,184
#      BatchNorm2d-232            [-1, 192, 7, 7]             384
#           MBConv-233            [-1, 192, 7, 7]               0
#           Conv2d-234           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-235           [-1, 1152, 7, 7]           2,304
#          Sigmoid-236           [-1, 1152, 7, 7]               0
#            Swish-237           [-1, 1152, 7, 7]               0
#           Conv2d-238           [-1, 1152, 7, 7]          28,800
#      BatchNorm2d-239           [-1, 1152, 7, 7]           2,304
#          Sigmoid-240           [-1, 1152, 7, 7]               0
#            Swish-241           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-242           [-1, 1152, 1, 1]               0
#           Linear-243                 [-1, 4608]       5,313,024
#          Sigmoid-244                 [-1, 4608]               0
#            Swish-245                 [-1, 4608]               0
#           Linear-246                 [-1, 1152]       5,309,568
#          Sigmoid-247                 [-1, 1152]               0
#          SEBlock-248           [-1, 1152, 1, 1]               0
#           Conv2d-249            [-1, 192, 7, 7]         221,184
#      BatchNorm2d-250            [-1, 192, 7, 7]             384
#           MBConv-251            [-1, 192, 7, 7]               0
#           Conv2d-252           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-253           [-1, 1152, 7, 7]           2,304
#          Sigmoid-254           [-1, 1152, 7, 7]               0
#            Swish-255           [-1, 1152, 7, 7]               0
#           Conv2d-256           [-1, 1152, 7, 7]          28,800
#      BatchNorm2d-257           [-1, 1152, 7, 7]           2,304
#          Sigmoid-258           [-1, 1152, 7, 7]               0
#            Swish-259           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-260           [-1, 1152, 1, 1]               0
#           Linear-261                 [-1, 4608]       5,313,024
#          Sigmoid-262                 [-1, 4608]               0
#            Swish-263                 [-1, 4608]               0
#           Linear-264                 [-1, 1152]       5,309,568
#          Sigmoid-265                 [-1, 1152]               0
#          SEBlock-266           [-1, 1152, 1, 1]               0
#           Conv2d-267            [-1, 192, 7, 7]         221,184
#      BatchNorm2d-268            [-1, 192, 7, 7]             384
#           MBConv-269            [-1, 192, 7, 7]               0
#           Conv2d-270           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-271           [-1, 1152, 7, 7]           2,304
#          Sigmoid-272           [-1, 1152, 7, 7]               0
#            Swish-273           [-1, 1152, 7, 7]               0
#           Conv2d-274           [-1, 1152, 7, 7]          10,368
#      BatchNorm2d-275           [-1, 1152, 7, 7]           2,304
#          Sigmoid-276           [-1, 1152, 7, 7]               0
#            Swish-277           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-278           [-1, 1152, 1, 1]               0
#           Linear-279                 [-1, 4608]       5,313,024
#          Sigmoid-280                 [-1, 4608]               0
#            Swish-281                 [-1, 4608]               0
#           Linear-282                 [-1, 1152]       5,309,568
#          Sigmoid-283                 [-1, 1152]               0
#          SEBlock-284           [-1, 1152, 1, 1]               0
#           Conv2d-285            [-1, 320, 7, 7]         368,640
#      BatchNorm2d-286            [-1, 320, 7, 7]             640
#           MBConv-287            [-1, 320, 7, 7]               0
#           Conv2d-288           [-1, 1280, 7, 7]         409,600
#      BatchNorm2d-289           [-1, 1280, 7, 7]           2,560
#          Sigmoid-290           [-1, 1280, 7, 7]               0
#            Swish-291           [-1, 1280, 7, 7]               0
# AdaptiveAvgPool2d-292           [-1, 1280, 1, 1]               0
#          Dropout-293                 [-1, 1280]               0
#           Linear-294                   [-1, 10]          12,810
# ================================================================
# Total params: 63,598,858
# Trainable params: 63,598,858
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 152.11
# Params size (MB): 242.61
# Estimated Total Size (MB): 395.29
# ----------------------------------------------------------------

# %% [markdown]
# # 3. 학습하기

# %%
# define loss function, optimizer, lr_scheduler
loss_func = nn.CrossEntropyLoss(reduction='sum')
opt = optim.Adam(model.parameters(), lr=0.01)

from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.1, patience=10)


# get current lr
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']


# calculate the metric per mini-batch
def metric_batch(output, target):
    pred = output.argmax(1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects


# calculate the loss per mini-batch
def loss_batch(loss_func, output, target, opt=None):
    loss_b = loss_func(output, target)
    metric_b = metric_batch(output, target)

    if opt is not None:
        opt.zero_grad()
        loss_b.backward()
        opt.step()
    
    return loss_b.item(), metric_b


# calculate the loss per epochs
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        output = model(xb)

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)

        running_loss += loss_b
        
        if metric_b is not None:
            running_metric += metric_b

        if sanity_check is True:
            break

    loss = running_loss / len_data
    metric = running_metric / len_data
    return loss, metric


# function to start training
def train_val(model, params):
    num_epochs=params['num_epochs']
    loss_func=params['loss_func']
    opt=params['optimizer']
    train_dl=params['train_dl']
    val_dl=params['val_dl']
    sanity_check=params['sanity_check']
    lr_scheduler=params['lr_scheduler']
    path2weights=params['path2weights']

    loss_history = {'train': [], 'val': []}
    metric_history = {'train': [], 'val': []}

    best_loss = float('inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    start_time = time.time()

    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr= {}'.format(epoch, num_epochs-1, current_lr))

        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss)
        metric_history['train'].append(train_metric)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)
        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), path2weights)
            print('Copied best model weights!')

        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print('Loading best model weights!')
            model.load_state_dict(best_model_wts)

        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
# define the training parameters
params_train = {
    'num_epochs':100,
    'optimizer':opt,
    'loss_func':loss_func,
    'train_dl':train_dl,
    'val_dl':val_dl,
    'sanity_check':False,
    'lr_scheduler':lr_scheduler,
    'path2weights':'./models/weights.pt',
}

# check the directory to save weights.pt
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSerror:
        print('Error')
createFolder('./models')

# %%
model, loss_hist, metric_hist = train_val(model, params_train)
# Out:
# Epoch 0/99, current lr= 0.01
# Copied best model weights!
# train loss: 2.098763, val loss: 1.932441, accuracy: 23.43, time: 0.8944 min
# ----------
# Epoch 1/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.811178, val loss: 1.762954, accuracy: 28.40, time: 1.7831 min
# ----------
# Epoch 2/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.723423, val loss: 1.749571, accuracy: 26.70, time: 2.6542 min
# ----------
# Epoch 3/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.673118, val loss: 1.723787, accuracy: 31.34, time: 3.5310 min
# ----------
# Epoch 4/99, current lr= 0.01
# train loss: 1.610887, val loss: 3.505069, accuracy: 20.01, time: 4.3930 min
# ----------
# Epoch 5/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.566746, val loss: 1.566972, accuracy: 37.14, time: 5.2602 min
# ----------
# Epoch 6/99, current lr= 0.01
# train loss: 1.562344, val loss: 1.736087, accuracy: 34.96, time: 6.1219 min
# ----------
# Epoch 7/99, current lr= 0.01
# train loss: 1.500864, val loss: 1.590615, accuracy: 42.70, time: 6.9806 min
# ----------
# Epoch 8/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.424801, val loss: 1.503993, accuracy: 43.51, time: 7.8612 min
# ----------
# Epoch 9/99, current lr= 0.01
# train loss: 1.393666, val loss: 1.617322, accuracy: 40.23, time: 8.7196 min
# ----------
# Epoch 10/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.292259, val loss: 1.464097, accuracy: 46.34, time: 9.5873 min
# ----------
# Epoch 11/99, current lr= 0.01
# train loss: 1.258632, val loss: 1.749139, accuracy: 41.27, time: 10.4471 min
# ----------
# Epoch 12/99, current lr= 0.01
# train loss: 1.200444, val loss: 1.703051, accuracy: 43.77, time: 11.3041 min
# ----------
# Epoch 13/99, current lr= 0.01
# train loss: 1.159462, val loss: 1.802763, accuracy: 42.04, time: 12.1724 min
# ----------
# Epoch 14/99, current lr= 0.01
# train loss: 1.117246, val loss: 1.727889, accuracy: 43.53, time: 13.0326 min
# ----------
# Epoch 15/99, current lr= 0.01
# train loss: 1.071929, val loss: 1.519789, accuracy: 50.32, time: 13.8890 min
# ----------
# Epoch 16/99, current lr= 0.01
# train loss: 1.024979, val loss: 1.497295, accuracy: 51.99, time: 14.7525 min
# ----------
# Epoch 17/99, current lr= 0.01
# train loss: 0.961202, val loss: 2.643986, accuracy: 41.93, time: 15.6083 min
# ----------
# Epoch 18/99, current lr= 0.01
# Copied best model weights!
# train loss: 0.927297, val loss: 1.350779, accuracy: 53.85, time: 16.4739 min
# ----------
# Epoch 19/99, current lr= 0.01
# Copied best model weights!
# train loss: 0.901294, val loss: 1.275373, accuracy: 56.29, time: 17.3464 min
# ----------
# Epoch 20/99, current lr= 0.01
# train loss: 0.837108, val loss: 1.523158, accuracy: 52.59, time: 18.2044 min
# ----------
# Epoch 21/99, current lr= 0.01
# Copied best model weights!
# train loss: 0.820082, val loss: 1.226547, accuracy: 59.36, time: 19.0816 min
# ----------
# Epoch 22/99, current lr= 0.01
# train loss: 0.777583, val loss: 1.761029, accuracy: 51.70, time: 19.9401 min
# ----------
# Epoch 23/99, current lr= 0.01
# train loss: 0.724445, val loss: 1.467075, accuracy: 54.81, time: 20.7976 min
# ----------
# Epoch 24/99, current lr= 0.01
# train loss: 0.692475, val loss: 1.712348, accuracy: 53.54, time: 21.6575 min
# ----------
# Epoch 25/99, current lr= 0.01
# train loss: 0.661735, val loss: 1.484028, accuracy: 53.75, time: 22.5161 min
# ----------
# Epoch 26/99, current lr= 0.01
# train loss: 0.603665, val loss: 1.959055, accuracy: 54.76, time: 23.3740 min
# ----------
# Epoch 27/99, current lr= 0.01
# train loss: 0.560260, val loss: 1.897093, accuracy: 54.99, time: 24.2317 min
# ----------
# Epoch 28/99, current lr= 0.01
# train loss: 0.545933, val loss: 1.469551, accuracy: 58.39, time: 25.0864 min
# ----------
# Epoch 29/99, current lr= 0.01
# train loss: 0.496380, val loss: 2.186248, accuracy: 51.48, time: 25.9547 min
# ----------
# Epoch 30/99, current lr= 0.01
# train loss: 0.428350, val loss: 1.888570, accuracy: 58.04, time: 26.8116 min
# ----------
# Epoch 31/99, current lr= 0.01
# train loss: 0.408322, val loss: 2.554800, accuracy: 48.04, time: 27.6660 min
# ----------
# Epoch 32/99, current lr= 0.01
# Loading best model weights!
# train loss: 0.381144, val loss: 2.047018, accuracy: 52.76, time: 28.5253 min
# ----------
# Epoch 33/99, current lr= 0.001
# train loss: 0.604422, val loss: 1.857013, accuracy: 53.36, time: 29.3793 min
# ----------
# Epoch 34/99, current lr= 0.001
# train loss: 0.492815, val loss: 1.577626, accuracy: 56.73, time: 30.2411 min
# ----------
# Epoch 35/99, current lr= 0.001
# train loss: 0.448815, val loss: 2.009884, accuracy: 53.00, time: 31.0995 min
# ----------
# Epoch 36/99, current lr= 0.001
# train loss: 0.390128, val loss: 1.564984, accuracy: 59.03, time: 31.9559 min
# ----------
# Epoch 37/99, current lr= 0.001
# train loss: 0.356892, val loss: 1.691174, accuracy: 59.30, time: 32.8197 min
# ----------
# Epoch 38/99, current lr= 0.001
# train loss: 0.329542, val loss: 2.323807, accuracy: 53.66, time: 33.6787 min
# ----------
# Epoch 39/99, current lr= 0.001
# train loss: 0.295778, val loss: 1.921912, accuracy: 57.39, time: 34.5336 min
# ----------
# Epoch 40/99, current lr= 0.001
# train loss: 0.251130, val loss: 2.272731, accuracy: 53.41, time: 35.3930 min
# ----------
# Epoch 41/99, current lr= 0.001
# train loss: 0.238882, val loss: 2.179423, accuracy: 57.33, time: 36.2495 min
# ----------
# Epoch 42/99, current lr= 0.001
# train loss: 0.208026, val loss: 2.218788, accuracy: 57.74, time: 37.1142 min
# ----------
# Epoch 43/99, current lr= 0.001
# Loading best model weights!
# train loss: 0.161740, val loss: 2.532528, accuracy: 54.02, time: 37.9697 min
# ----------
# Epoch 44/99, current lr= 0.0001
# train loss: 0.687659, val loss: 1.470921, accuracy: 52.88, time: 38.8259 min
# ----------
# Epoch 45/99, current lr= 0.0001
# Copied best model weights!
# train loss: 0.624608, val loss: 1.224368, accuracy: 59.20, time: 39.6980 min
# ----------
# Epoch 46/99, current lr= 0.0001
# Copied best model weights!
# train loss: 0.590171, val loss: 1.205770, accuracy: 59.72, time: 40.5629 min
# ----------
# Epoch 47/99, current lr= 0.0001
# train loss: 0.574782, val loss: 1.703878, accuracy: 53.55, time: 41.4192 min
# ----------
# Epoch 48/99, current lr= 0.0001
# train loss: 0.549786, val loss: 1.512490, accuracy: 53.36, time: 42.2798 min
# ----------
# Epoch 49/99, current lr= 0.0001
# train loss: 0.542433, val loss: 1.871280, accuracy: 52.99, time: 43.1354 min
# ----------
# Epoch 50/99, current lr= 0.0001
# train loss: 0.530130, val loss: 1.634742, accuracy: 53.26, time: 44.0008 min
# ----------
# Epoch 51/99, current lr= 0.0001
# train loss: 0.515626, val loss: 1.529925, accuracy: 53.60, time: 44.8568 min
# ----------
# Epoch 52/99, current lr= 0.0001
# train loss: 0.505770, val loss: 1.780312, accuracy: 52.61, time: 45.7102 min
# ----------
# Epoch 53/99, current lr= 0.0001
# train loss: 0.502139, val loss: 1.838153, accuracy: 54.74, time: 46.5701 min
# ----------
# Epoch 54/99, current lr= 0.0001
# train loss: 0.479903, val loss: 1.507605, accuracy: 56.36, time: 47.4258 min
# ----------
# Epoch 55/99, current lr= 0.0001
# train loss: 0.463856, val loss: 3.738294, accuracy: 36.60, time: 48.2839 min
# ----------
# Epoch 56/99, current lr= 0.0001
# train loss: 0.456233, val loss: 1.344006, accuracy: 61.10, time: 49.1426 min
# ----------
# Epoch 57/99, current lr= 0.0001
# Loading best model weights!
# train loss: 0.449205, val loss: 1.667675, accuracy: 54.05, time: 49.9984 min
# ----------
# Epoch 58/99, current lr= 1e-05
# train loss: 0.583261, val loss: 1.296150, accuracy: 58.11, time: 50.8617 min
# ----------
# Epoch 59/99, current lr= 1e-05
# train loss: 0.585511, val loss: 1.280133, accuracy: 59.25, time: 51.7168 min
# ----------
# Epoch 60/99, current lr= 1e-05
# train loss: 0.582904, val loss: 1.439125, accuracy: 56.30, time: 52.5717 min
# ----------
# Epoch 61/99, current lr= 1e-05
# train loss: 0.572039, val loss: 1.442607, accuracy: 54.19, time: 53.4310 min
# ----------
# Epoch 62/99, current lr= 1e-05
# train loss: 0.569053, val loss: 1.265364, accuracy: 59.75, time: 54.2860 min
# ----------
# Epoch 63/99, current lr= 1e-05
# train loss: 0.572153, val loss: 1.458386, accuracy: 55.80, time: 55.1513 min
# ----------
# Epoch 64/99, current lr= 1e-05
# train loss: 0.569181, val loss: 1.271884, accuracy: 59.15, time: 56.0076 min
# ----------
# Epoch 65/99, current lr= 1e-05
# train loss: 0.563232, val loss: 1.415911, accuracy: 57.77, time: 56.8618 min
# ----------
# Epoch 66/99, current lr= 1e-05
# train loss: 0.564182, val loss: 1.534464, accuracy: 55.16, time: 57.7197 min
# ----------
# Epoch 67/99, current lr= 1e-05
# train loss: 0.559166, val loss: 1.899354, accuracy: 50.68, time: 58.5745 min
# ----------
# Epoch 68/99, current lr= 1e-05
# Loading best model weights!
# train loss: 0.564105, val loss: 1.375847, accuracy: 58.36, time: 59.4296 min
# ----------
# Epoch 69/99, current lr= 1.0000000000000002e-06
# train loss: 0.585757, val loss: 1.831897, accuracy: 49.16, time: 60.2893 min
# ----------
# Epoch 70/99, current lr= 1.0000000000000002e-06
# train loss: 0.582532, val loss: 1.401195, accuracy: 57.85, time: 61.1431 min
# ----------
# Epoch 71/99, current lr= 1.0000000000000002e-06
# train loss: 0.571859, val loss: 1.731451, accuracy: 51.42, time: 62.0068 min
# ----------
# Epoch 72/99, current lr= 1.0000000000000002e-06
# train loss: 0.580264, val loss: 1.318173, accuracy: 58.76, time: 62.8643 min
# ----------
# Epoch 73/99, current lr= 1.0000000000000002e-06
# train loss: 0.585225, val loss: 1.305744, accuracy: 58.91, time: 63.7184 min
# ----------
# Epoch 74/99, current lr= 1.0000000000000002e-06
# train loss: 0.587480, val loss: 2.159645, accuracy: 46.83, time: 64.5758 min
# ----------
# Epoch 75/99, current lr= 1.0000000000000002e-06
# train loss: 0.574296, val loss: 1.649488, accuracy: 53.17, time: 65.4262 min
# ----------
# Epoch 76/99, current lr= 1.0000000000000002e-06
# train loss: 0.579445, val loss: 1.208579, accuracy: 59.05, time: 66.2775 min
# ----------
# Epoch 77/99, current lr= 1.0000000000000002e-06
# train loss: 0.577995, val loss: 1.387506, accuracy: 57.40, time: 67.1329 min
# ----------
# Epoch 78/99, current lr= 1.0000000000000002e-06
# train loss: 0.579190, val loss: 2.556035, accuracy: 43.08, time: 67.9830 min
# ----------
# Epoch 79/99, current lr= 1.0000000000000002e-06
# Loading best model weights!
# train loss: 0.582570, val loss: 1.388720, accuracy: 57.31, time: 68.8436 min
# ----------
# Epoch 80/99, current lr= 1.0000000000000002e-07
# train loss: 0.577277, val loss: 1.232538, accuracy: 58.53, time: 69.6955 min
# ----------
# Epoch 81/99, current lr= 1.0000000000000002e-07
# Copied best model weights!
# train loss: 0.586316, val loss: 1.179073, accuracy: 59.96, time: 70.5559 min
# ----------
# Epoch 82/99, current lr= 1.0000000000000002e-07
# train loss: 0.577474, val loss: 1.445172, accuracy: 56.26, time: 71.4111 min
# ----------
# Epoch 83/99, current lr= 1.0000000000000002e-07
# train loss: 0.591628, val loss: 1.448630, accuracy: 57.34, time: 72.2647 min
# ----------
# Epoch 84/99, current lr= 1.0000000000000002e-07
# train loss: 0.583125, val loss: 1.698507, accuracy: 52.71, time: 73.1169 min
# ----------
# Epoch 85/99, current lr= 1.0000000000000002e-07
# train loss: 0.579761, val loss: 1.585850, accuracy: 53.44, time: 73.9739 min
# ----------
# Epoch 86/99, current lr= 1.0000000000000002e-07
# train loss: 0.581889, val loss: 2.340981, accuracy: 44.50, time: 74.8281 min
# ----------
# Epoch 87/99, current lr= 1.0000000000000002e-07
# train loss: 0.588967, val loss: 1.853176, accuracy: 49.88, time: 75.6915 min
# ----------
# Epoch 88/99, current lr= 1.0000000000000002e-07
# train loss: 0.593615, val loss: 1.500390, accuracy: 55.61, time: 76.5434 min
# ----------
# Epoch 89/99, current lr= 1.0000000000000002e-07
# train loss: 0.576341, val loss: 1.282407, accuracy: 59.08, time: 77.3956 min
# ----------
# Epoch 90/99, current lr= 1.0000000000000002e-07
# train loss: 0.570865, val loss: 1.404776, accuracy: 57.17, time: 78.2543 min
# ----------
# Epoch 91/99, current lr= 1.0000000000000002e-07
# train loss: 0.579046, val loss: 1.382823, accuracy: 57.63, time: 79.1058 min
# ----------
# Epoch 92/99, current lr= 1.0000000000000002e-07
# Loading best model weights!
# train loss: 0.582529, val loss: 1.196735, accuracy: 60.88, time: 79.9605 min
# ----------
# Epoch 93/99, current lr= 1.0000000000000004e-08
# train loss: 0.578365, val loss: 1.408596, accuracy: 57.64, time: 80.8161 min
# ----------
# Epoch 94/99, current lr= 1.0000000000000004e-08
# train loss: 0.581820, val loss: 1.448033, accuracy: 56.07, time: 81.6664 min
# ----------
# Epoch 95/99, current lr= 1.0000000000000004e-08
# train loss: 0.586173, val loss: 1.476469, accuracy: 57.59, time: 82.5239 min
# ----------
# Epoch 96/99, current lr= 1.0000000000000004e-08
# train loss: 0.571128, val loss: 1.278315, accuracy: 59.72, time: 83.3729 min
# ----------
# Epoch 97/99, current lr= 1.0000000000000004e-08
# train loss: 0.590188, val loss: 1.914091, accuracy: 50.11, time: 84.2218 min
# ----------
# Epoch 98/99, current lr= 1.0000000000000004e-08
# train loss: 0.579260, val loss: 1.365786, accuracy: 56.71, time: 85.0755 min
# ----------
# Epoch 99/99, current lr= 1.0000000000000004e-08
# train loss: 0.583602, val loss: 2.034727, accuracy: 48.91, time: 85.9243 min
# ----------

# %%
num_epochs = params_train['num_epochs']

# Plot train-val loss
plt.title('Train-Val Loss')
plt.plot(range(1, num_epochs+1), loss_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), loss_hist['val'], label='val')
plt.ylabel('Loss')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()

# plot train-val accuracy
plt.title('Train-Val Accuracy')
plt.plot(range(1, num_epochs+1), metric_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), metric_hist['val'], label='val')
plt.ylabel('Accuracy')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()
